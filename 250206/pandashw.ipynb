# %%
#6.12 판다스) 리스트로 시리즈생성
import pandas as pd
import numpy as np

a = pd.Series([1, 2, 3, 4]) # 인덱스를 지정하지 않아서 0, 1, 2, 3으로 지정됨
print(a)

b = pd.Series([1, 2, 3], index = ['a', 'b', 'c'])
print(b)

#6.13 리스트로 데이터 프레임 생성
list1 = list([['한빛', '남자', '20', '180'],
                ['한결', '남자', '21', '177'],
                ['한라', '여자', '20', '160']])
col_names = ['이름', '성별', '나이', '키']

pd.DataFrame(list1, columns = col_names).to_csv('test.csv', index = False)   #csv로저장
pd.DataFrame(list1, columns = col_names).to_excel('test.xlsx', index = False)

#6.14
dict1 = {'이름':{0:'한빛', 1:'한결', 2:'한라'},
         '성별':{0:'남자', 1:'남자', 2:'여자'},
         '나이':{0:'20', 1:'21', 2:'20'},
         '키':{0:'180', 1:'177', 2:'160'}}
pd.DataFrame(dict1).to_csv('test2.csv', index = False)
pd.DataFrame(dict1).to_excel('test2.xlsx', index = False)

#6.15
#배열
arr1 = np.array([['한빛', '남자', '20', '180'],
                ['한결', '남자', '21', '177'],
                ['한라', '여자', '20', '160']])

#열 이름 리스트
col_names = ['이름', '성별', '나이', '키']

#데이터프레임 생성하기
pd.DataFrame(arr1, columns = col_names)
pd.DataFrame(arr1, columns = col_names).to_csv('test3.csv', index = False)
pd.DataFrame(arr1, columns = col_names).to_excel('test3.xlsx', index = False)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64

# %%
from google.colab import files

f = files.upload()
# Out:
#      <input type="file" id="files-c769347d-c842-496d-8b70-1c569a1fef66" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c769347d-c842-496d-8b70-1c569a1fef66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_excel('./gni.xlsx')
print(df.columns)
# Out:
# Index(['연도', 'gni'], dtype='object')

# %%
import pandas as pd

print(list(df.columns))
gni = []
for i in range(0, len(df)):
    # print(df.loc[i])
    gni.append(list(df.loc[i]))


print(gni)
# Out:
# ['연도', 'gni']
# [['2014', '3,094.8'], ['2015', '3,260.2'], ['2016', '3,411.2'], ['2017', '3,588.6'], ['2018', '3,693.0'], ['2019', '3,753.9'], ['2020', '3,776.6'], ['2021', '4,065.4'], ['2022p', '4,248.7'], ['2023p', '4,405.1']]

# %%
import pandas as pd

df = pd.read_csv('./test.csv', encoding = 'utf8')
print(df.columns)
print(df.columns)
data = []
for i in range(0, len(df)):

    data.append(list(df.loc[i]) + [i])
    # data[i].append(i)
cols = list(df.columns)
cols.append('비고2')
# col_names = ['이름', '성별', '나이', '키', '비고2']

pd.DataFrame(data, columns = cols).to_csv('test4.csv', index = False)
pd.DataFrame(data, columns = cols).to_excel('test4.xlsx', index = False)

print(data)

import numpy as np
# 키의 최소값, 최대값, 평균, 표준편차

height = []

df = pd.read_csv('./test.csv', encoding = 'utf8')
# for i in range(0, len(data)):
    # height.append(data[i][3])
for i in range(0, len(df)):
    height.append(int(df.loc[i][3]))

print(height)

print('키의 최소값 : ', np.min(height))
print('키의 최대값 : ', np.max(height))
print('키의 평균 : ', np.average(height))
print('키의 중위값 : ', np.median(height))
print('키의 표준편차 : ', np.std(height))
# Out:
# Index(['이름', '성별', '나이', '키'], dtype='object')
# Index(['이름', '성별', '나이', '키'], dtype='object')
# [['한빛', '남자', 20, 180, 0], ['한결', '남자', 21, 177, 1], ['한라', '여자', 20, 160, 2]]
# [180, 177, 160]
# 키의 최소값 :  160
# 키의 최대값 :  180
# 키의 평균 :  172.33333333333334
# 키의 중위값 :  177.0
# 키의 표준편차 :  8.806563209081938
# <ipython-input-73-6ccb6f4878f7>:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   height.append(int(df.loc[i][3]))

# %%
list1 = list([['허준호','남자','30','183'],
['이가원','여자','24','162'],
['배규민','남자','23','179'],
['고고림','남자','21','182'],
['이새봄','여자','28','160'],
['이보람','여자','26','163'],
['이루리','여자','24','157'],
['오다현','여자','24','172']])
col_names = ['이름','성별','나이','키']
df = pd.DataFrame(list1, columns = col_names)

# %%
df.describe()
# Out:
#          이름  성별  나이    키
# count     8   8   8    8
# unique    8   2   6    8
# top     허준호  여자  24  183
# freq      1   5   3    1

# %%
df.head(2)
# Out:
#     이름  성별  나이    키
# 0  허준호  남자  30  183
# 1  이가원  여자  24  162

# %%
df.tail(2)
# Out:
#     이름  성별  나이    키
# 6  이루리  여자  24  157
# 7  오다현  여자  24  172

# %%
df.sort_index(axis = 0).head()
# Out:
#     이름  성별  나이    키
# 0  허준호  남자  30  183
# 1  이가원  여자  24  162
# 2  배규민  남자  23  179
# 3  고고림  남자  21  182
# 4  이새봄  여자  28  160

# %%
#나이 열과 키 열을 기준으로 행을 정렬하기
df.sort_values(by = ['나이', '키'], ascending = False).head()
# Out:
#     이름  성별  나이    키
# 0  허준호  남자  30  183
# 4  이새봄  여자  28  160
# 5  이보람  여자  26  163
# 7  오다현  여자  24  172
# 1  이가원  여자  24  162

# %%
df[['이름', '키']].head()
# Out:
#     이름    키
# 0  허준호  183
# 1  이가원  162
# 2  배규민  179
# 3  고고림  182
# 4  이새봄  160

# %%
df.iloc[0 : 2, 1 : 2] #2행까지 1열만
# Out:
#    성별
# 0  남자
# 1  여자

# %%
# Out:
# 0    183
# 1    162
# 2    179
# 3    182
# 4    160
# 5    163
# 6    157
# 7    172
# Name: 키, dtype: object

# %%
df[df['키'] > 180].head() #자료형이 문자열이기 때문
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-a8ae255a73e6> in <cell line: 0>()
# ----> 1 df[df['키'] > 180].head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6117         rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6118
# ...

# %%
list1 = list([['허준호', '남자', 30, 183],
 ['이가원', '여자', 24, 162],
['배규민', '남자', 23, 179],
['고고림', '남자', 21, 182],
['이새봄', '여자', 28, 160],
['이보람', '여자', 26, 163],
['이루리', '여자', 24, 157],
['오다현', '여자', 24, 172]])
col_names = ['이름', '성별', '나이', '키']
df1 = pd.DataFrame(list1, columns = col_names)

df1[df1['키'] > 170]
# Out:
#     이름  성별  나이    키
# 0  허준호  남자  30  183
# 2  배규민  남자  23  179
# 3  고고림  남자  21  182
# 7  오다현  여자  24  172

# %%
df1[df1['나이'].isin([21, 23])] #나이가 21세 또는 23세인 사람을 조회
# Out:
#     이름  성별  나이    키
# 2  배규민  남자  23  179
# 3  고고림  남자  21  182

# %%
df1[(df1['성별'] == '여자') & (df1['키'] > 160)]
# Out:
#     이름  성별  나이    키
# 1  이가원  여자  24  162
# 5  이보람  여자  26  163
# 7  오다현  여자  24  172

# %%
df1[(df1['나이'] >= 28) | (df['성별'] == '남자')]
# Out:
#     이름  성별  나이    키
# 0  허준호  남자  30  183
# 2  배규민  남자  23  179
# 3  고고림  남자  21  182
# 4  이새봄  여자  28  160

# %%
#6.31
df1[df1['이름'].str.contains('봄')]
# Out:
#     이름  성별  나이    키
# 4  이새봄  여자  28  160

# %%
#6.32
df1.describe()
# Out:
#               나이           키
# count   8.000000    8.000000
# mean   25.000000  169.750000
# std     2.878492   10.552589
# min    21.000000  157.000000
# 25%    23.750000  161.500000
# 50%    24.000000  167.500000
# 75%    26.500000  179.750000
# max    30.000000  183.000000

# %%
#6.33 4번행의 키 열 값을 5만큼 증가시킨다
df1.loc[4, '키'] = df1.loc[4, '키'] + 5
df1.loc[[4]]
# Out:
#     이름  성별  나이    키
# 4  이새봄  여자  28  165

# %%
#6.34
df1.loc[1:3, '키'] = ['모름'] * 3
df1
# Out:
#     이름  성별  나이    키
# 0  허준호  남자  30  183
# 1  이가원  여자  24   모름
# 2  배규민  남자  23   모름
# 3  고고림  남자  21   모름
# 4  이새봄  여자  28  165
# 5  이보람  여자  26  163
# 6  이루리  여자  24  157
# 7  오다현  여자  24  172

# %%
#6.35
df1.set_index('이름', inplace = True)
df1.head(3)
# Out:
#      성별  나이    키
# 이름
# 허준호  남자  30  183
# 이가원  여자  24  162
# 배규민  남자  23  179

# %%
#6.36
df1['보너스'] = df1['나이'] * 10000
df1.head(3)
# Out:
#      성별  나이    키     보너스
# 이름
# 허준호  남자  30  183  300000
# 이가원  여자  24  162  240000
# 배규민  남자  23  179  230000

# %%
#6.37
df1.drop('보너스', axis = 1, inplace = True)
df1.head(3)
# Out:
#      성별  나이    키
# 이름
# 허준호  남자  30  183
# 이가원  여자  24  162
# 배규민  남자  23  179

# %%
#6.38 인덱스 변경 2
df1.reset_index(inplace = True)
df1.head(3)
# Out:
#     이름  성별  나이    키
# 0  허준호  남자  30  183
# 1  이가원  여자  24  162
# 2  배규민  남자  23  179

# %%
#6.39 데이터 치환
rep_cond = {'성별' : {'남자' : 1, '여자' : 0}}
df2 = df.replace(rep_cond)
df2.head(3)
# Out:
# <ipython-input-126-858f8394595d>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df.replace(rep_cond)
#     이름  성별  나이    키
# 0  허준호   1  30  183
# 1  이가원   0  24  162
# 2  배규민   1  23  179

# %%
#6.40 데이터프레임의 값 연산
#성별 평균 키
mean_by_gender = df1.groupby(by = ['성별'], as_index = False)['키'].mean( )
mean_by_gender.rename(columns = {'키':'평균 키'}, inplace = True)

#성별 키의 표준편차
std_by_gender = df1.groupby(by = ['성별'], as_index=False)['키'].std( )
std_by_gender.rename(columns = {'키':'키의 표준편차'}, inplace = True)

new_df = pd.merge(mean_by_gender, std_by_gender)
new_df
# Out:
#    성별        평균 키   키의 표준편차
# 0  남자  181.333333  2.081666
# 1  여자  162.800000  5.630275
