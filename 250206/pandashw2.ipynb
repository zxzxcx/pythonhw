# %%
import pandas as pd

col_names = ['과목번호', '과목명', '강의실', '시간수']
list1 = list([['C1', '인공지능개론', 'R1', 3],
['C2', '웃음치료', 'R2', 2],
['C3', '경영학', 'R3', 3],
['C4', '3D디자인', 'R4', 4],
['C5', '스포츠경영', 'R2', 2],
['C6', '예술의 세계', 'R3', 1]
])

df = pd.DataFrame(list1, columns = col_names)
df.to_csv('./timetable.csv', header = True, index = False,
encoding = 'utf-8')

df2 = pd.read_csv('./timetable.csv', sep = ',')
df2['교수'] = ['김예희', '오정현', '인세훈', '이새봄', '배유진', '이가원']
df2['비고'] = ['0','0','0','0','0','1']
df2
# Out:
#   과목번호     과목명 강의실  시간수   교수 비고
# 0   C1  인공지능개론  R1    3  김예희  0
# 1   C2    웃음치료  R2    2  오정현  0
# 2   C3     경영학  R3    3  인세훈  0
# 3   C4   3D디자인  R4    4  이새봄  0
# 4   C5   스포츠경영  R2    2  배유진  0
# 5   C6  예술의 세계  R3    1  이가원  1

# %%
max_hour = df2.groupby(by = ['강의실'],
 as_index = False)['시간수'].max( )
max_hour
# Out:
#   강의실  시간수
# 0  R1    3
# 1  R2    2
# 2  R3    3
# 3  R4    4
