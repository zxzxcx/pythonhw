# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [1, 4, 8, 16]
plt.plot(x, y, 'ro', label = 'height', color = 'b') #산점도
# plt.axis([0, 6, 0, 20])
plt.title('blah blah')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

plt.plot(x, y) #꺾은선 그래프
plt.show()

plt.bar(x,y) #막대 그래프
plt.show()
# Out:
# <ipython-input-12-def0bdc58ede>:5: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x, y, 'ro', label = 'height', color = 'b') #산점도
